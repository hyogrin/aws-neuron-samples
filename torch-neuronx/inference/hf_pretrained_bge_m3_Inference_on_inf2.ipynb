# %% [markdown]
# # HuggingFace Pretrained BGE M3 Inference on Inf2

# %% [markdown]
# ## Introduction
#
# This notebook demonstrates how to compile and run a HuggingFace 🤗 BGE-M3(xlm-roberta) model for accelerated inference on Neuron. This notebook will use the ['BAAI/bge-m3'](https://huggingface.co/BAAI/bge-m3) model, which is primarily used for word embeddings.
#
# This Jupyter notebook should be run on a Inf2 instance (`inf2.8xlarge` or larger).

# %% [markdown]
# Verify that this Jupyter notebook is running the Python kernel environment that was set up according to the [PyTorch Installation Guide](https://awsdocs-neuron.readthedocs-hosted.com/en/latest/general/setup/torch-neuronx.html#setup-torch-neuronx). You can select the kernel from the 'Kernel -> Change Kernel' option on the top of this Jupyter notebook page.

# %% [markdown]
# ## Install Dependencies
# This tutorial requires the following pip packages:
#
# - `torch-neuronx`
# - `neuronx-cc`
# - `transformers`
#
# Most of these packages will be installed when configuring your environment using the Trn1 setup guide. The additional dependencies must be installed here:

# %%
# %env TOKENIZERS_PARALLELISM=True #Supresses tokenizer warnings making errors easier to detect
# !pip install -U transformers
# Out:
# env: TOKENIZERS_PARALLELISM=True #Supresses tokenizer warnings making errors easier to detect
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com
# Collecting transformers
#   Downloading transformers-4.41.0-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (3.13.4)
# Collecting huggingface-hub<1.0,>=0.23.0 (from transformers)
#   Downloading huggingface_hub-0.23.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.17 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (6.0.1)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2024.5.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (2.31.0)
# Collecting tokenizers<0.20,>=0.19 (from transformers)
#   Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.4.1 (from transformers)
#   Downloading safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: tqdm>=4.27 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from transformers) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.11.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from requests->transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/aws_neuronx_venv_pytorch_2_1/lib/python3.10/site-packages (from requests->transformers) (2024.2.2)
# Downloading transformers-4.41.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 15.2 MB/s eta 0:00:00:00:0100:01
# Downloading huggingface_hub-0.23.0-py3-none-any.whl (401 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 4.3 MB/s eta 0:00:00:00:01
# Downloading regex-2024.5.15-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (775 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 775.1/775.1 kB 8.7 MB/s eta 0:00:00:00:01
# Downloading safetensors-0.4.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.2 MB/s eta 0:00:00:00:01
# Downloading tokenizers-0.19.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 15.4 MB/s eta 0:00:00:00:01
# Installing collected packages: safetensors, regex, huggingface-hub, tokenizers, transformers
# Successfully installed huggingface-hub-0.23.0 regex-2024.5.15 safetensors-0.4.3 tokenizers-0.19.1 transformers-4.41.0

# %% [markdown]
# ## Compile the model into an AWS Neuron optimized TorchScript

# %% [markdown]
# In the following section, we load the model and tokenizer, get s sample input, run inference on CPU, compile the model for Neuron using `torch_neuronx.trace()` and save the optimized model as `TorchScript`.
#
# `torch_neuronx.trace()` expects a tensor or tuple of tensor inputs to use for tracing, so we unpack the tokenzier output. Additionally, the input shape that's used duing compilation must match the input shape that's used during inference. To handle this, we pad the inputs to the maximum size that we will see during inference.

# %%
import torch
import torch_neuronx
from transformers import AutoTokenizer, AutoModel


def cls_pooling(model_output, attention_mask):
    return model_output[0][:,0]



# Create the tokenizer and model
tokenizer = AutoTokenizer.from_pretrained('BAAI/bge-m3')
model = AutoModel.from_pretrained('BAAI/bge-m3')

# Get an example input
sentences = ['This is an example sentence', 'Each sentence is converted']

# Tokenize sentences
encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

# Compute token embeddings
with torch.no_grad():
    model_output_cpu = model(**encoded_input)

# Perform pooling. In this case, cls pooling.
sentence_embeddings_cpu = cls_pooling(model_output_cpu, encoded_input['attention_mask'])

print("Sentence embeddings cpu:")
print(sentence_embeddings_cpu)

encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')
example = (
    encoded_input['input_ids'],
    encoded_input['attention_mask'],
)

# Compile the model
model_neuron = torch_neuronx.trace(model,example)

# Save the TorchScript for inference deployment
filename = 'model.pt'
torch.jit.save(model_neuron, filename)
# Out:
# Sentence embeddings cpu:
# tensor([[-0.3375,  1.2365, -1.0101,  ..., -0.6634, -0.0480, -0.3944],
#         [ 0.3626, -0.0248, -0.4376,  ..., -0.0577, -0.8273,  1.4676]])
# 2024-05-21T15:57:36Z Running DoNothing
# 2024-05-21T15:57:36Z DoNothing finished after 0.000 seconds
# 2024-05-21T15:57:36Z Running AliasDependencyInduction
# 2024-05-21T15:57:36Z AliasDependencyInduction finished after 0.005 seconds
# 2024-05-21T15:57:36Z Running CanonicalizeIR
# 2024-05-21T15:57:36Z CanonicalizeIR finished after 0.024 seconds
# 2024-05-21T15:57:36Z Running LegalizeCCOpLayout
# 2024-05-21T15:57:37Z LegalizeCCOpLayout finished after 0.024 seconds
# 2024-05-21T15:57:37Z Running ResolveComplicatePredicates
# 2024-05-21T15:57:37Z ResolveComplicatePredicates finished after 0.022 seconds
# 2024-05-21T15:57:37Z Running AffinePredicateResolution
# 2024-05-21T15:57:37Z AffinePredicateResolution finished after 0.024 seconds
# 2024-05-21T15:57:37Z Running EliminateDivs
# 2024-05-21T15:57:37Z EliminateDivs finished after 0.023 seconds
# 2024-05-21T15:57:37Z Running PerfectLoopNest
# 2024-05-21T15:57:37Z PerfectLoopNest finished after 0.023 seconds
# 2024-05-21T15:57:37Z Running Simplifier
# 2024-05-21T15:57:37Z Simplifier finished after 0.106 seconds
# 2024-05-21T15:57:37Z Running GenericAccessSimplifier
# 2024-05-21T15:57:37Z GenericAccessSimplifier finished after 0.020 seconds
# 2024-05-21T15:57:37Z Running TCTransform
# 2024-05-21T15:57:37Z TCTransform finished after 0.020 seconds
# 2024-05-21T15:57:37Z Running CommuteConcat
# 2024-05-21T15:57:37Z CommuteConcat finished after 0.020 seconds
# 2024-05-21T15:57:37Z Running LowerTensorOp
# 2024-05-21T15:57:37Z LowerTensorOp finished after 0.417 seconds
# 2024-05-21T15:57:37Z Running ExpandBatchNorm
# 2024-05-21T15:57:37Z ExpandBatchNorm finished after 0.055 seconds
# 2024-05-21T15:57:37Z Running TCTransform
# 2024-05-21T15:57:37Z TCTransform finished after 0.076 seconds
# 2024-05-21T15:57:37Z Running EliminateDivs
# 2024-05-21T15:57:37Z EliminateDivs finished after 0.043 seconds
# 2024-05-21T15:57:37Z Running GenericAccessSimplifier
# 2024-05-21T15:57:37Z GenericAccessSimplifier finished after 0.049 seconds
# 2024-05-21T15:57:37Z Running CanonicalizeIR
# 2024-05-21T15:57:38Z CanonicalizeIR finished after 0.046 seconds
# 2024-05-21T15:57:38Z Running TensorOpFusion
# 2024-05-21T15:57:38Z TensorOpFusion finished after 0.066 seconds
# 2024-05-21T15:57:38Z Running TensorOpTransform
# 2024-05-21T15:57:38Z TensorOpTransform finished after 0.219 seconds
# 2024-05-21T15:57:38Z Running LateLowerTensorOp
# 2024-05-21T15:57:38Z LateLowerTensorOp finished after 0.079 seconds
# 2024-05-21T15:57:38Z Running MemcpyElimination
# 2024-05-21T15:57:42Z MemcpyElimination finished after 3.996 seconds
# 2024-05-21T15:57:42Z Running LoopFusion
# 2024-05-21T15:57:45Z LoopFusion finished after 2.628 seconds
# 2024-05-21T15:57:45Z Running Rematerialization
# 2024-05-21T15:57:45Z Rematerialization finished after 0.098 seconds
# 2024-05-21T15:57:45Z Running Simplifier
# 2024-05-21T15:57:46Z Simplifier finished after 0.581 seconds
# 2024-05-21T15:57:46Z Running Delinearization
# 2024-05-21T15:57:47Z Delinearization finished after 0.292 seconds
# 2024-05-21T15:57:47Z Running AliasDependencyElimination
# 2024-05-21T15:59:52Z LegalizeSundaAccess finished after 0.281 seconds
# 2024-05-21T15:59:52Z Running RelaxPredicates
# 2024-05-21T15:59:53Z RelaxPredicates finished after 0.036 seconds
# 2024-05-21T15:59:53Z Running TensorInitialization
# 2024-05-21T15:59:54Z TensorInitialization finished after 0.018 seconds
# 2024-05-21T15:59:54Z Running NeuronSimplifyPredicates
# 2024-05-21T15:59:55Z NeuronSimplifyPredicates finished after 0.021 seconds
# 2024-05-21T15:59:55Z Running ExpandISAMacro
# 2024-05-21T15:59:56Z ExpandISAMacro finished after 0.378 seconds
# 2024-05-21T15:59:56Z Running SimplifyNeuronTensor
# 2024-05-21T15:59:57Z SimplifyNeuronTensor finished after 0.091 seconds
# 2024-05-21T15:59:57Z Running DMALocalityOpt
# 2024-05-21T15:59:58Z DMALocalityOpt finished after 0.011 seconds
# 2024-05-21T15:59:58Z Running DataStreaming
# 2024-05-21T16:00:00Z DataStreaming finished after 0.055 seconds
# 2024-05-21T16:00:00Z Running SFKVectorizer
# 2024-05-21T16:00:05Z SFKVectorizer finished after 3.511 seconds
# 2024-05-21T16:00:05Z Running LateLegalizeInst
# 2024-05-21T16:00:06Z LateLegalizeInst finished after 0.030 seconds
# 2024-05-21T16:00:06Z Running CoalesceCCOp
# 2024-05-21T16:00:07Z CoalesceCCOp finished after 0.030 seconds
# 2024-05-21T16:00:07Z Running SimpleAllReduceTiling
# 2024-05-21T16:00:08Z SimpleAllReduceTiling finished after 0.029 seconds
# 2024-05-21T16:00:08Z Running StaticProfiler
# 2024-05-21T16:00:09Z StaticProfiler finished after 0.068 seconds
# 2024-05-21T16:00:09Z Running SplitAPUnionSets
# 2024-05-21T16:00:11Z SplitAPUnionSets finished after 0.197 seconds
# 2024-05-21T16:00:11Z Running DumpGraphAndMetadata
# 2024-05-21T16:00:11Z DumpGraphAndMetadata finished after 0.064 seconds
# 2024-05-21T16:00:11Z Running BirCodeGenLoop
# 2024-05-21T16:00:12Z BirCodeGenLoop finished after 0.712 seconds
# 2024-05-21T16:00:23Z Running mod_parallel_pass
# 2024-05-21T16:00:23Z Running rewrite_matmult_sparse
# 2024-05-21T16:00:23Z rewrite_matmult_sparse finished after 0.000 seconds
# 2024-05-21T16:00:23Z Running birverifier
# 2024-05-21T16:00:23Z birverifier finished after 0.041 seconds
# 2024-05-21T16:00:23Z Running expand_replication
# 2024-05-21T16:00:23Z expand_replication finished after 0.000 seconds
# 2024-05-21T16:00:23Z Running unroll
# 2024-05-21T16:00:23Z unroll finished after 0.141 seconds
# 2024-05-21T16:00:23Z Running psum_legalization
# 2024-05-21T16:00:23Z psum_legalization finished after 0.003 seconds
# 2024-05-21T16:00:23Z Running error_injector
# 2024-05-21T16:00:23Z error_injector finished after 0.000 seconds
# 2024-05-21T16:00:23Z Running constant_propagate
# 2024-05-21T16:00:23Z constant_propagate finished after 0.016 seconds
# 2024-05-21T16:00:23Z Running vn_splitter
# 2024-05-21T16:00:23Z vn_splitter finished after 0.013 seconds
# 2024-05-21T16:00:23Z Running lower_ac
# 2024-05-21T16:00:23Z lower_ac finished after 0.002 seconds
# 2024-05-21T16:00:23Z Running input_dma_coalescing
# 2024-05-21T16:00:23Z input_dma_coalescing finished after 0.005 seconds
# 2024-05-21T16:00:23Z Running early_peephole_opts
# 2024-05-21T16:00:23Z early_peephole_opts finished after 0.001 seconds
# 2024-05-21T16:00:23Z Running pre_sched
# 2024-05-21T16:00:23Z pre_sched finished after 0.085 seconds
# 2024-05-21T16:00:23Z Running tensor_copy_elim
# 2024-05-21T16:00:23Z tensor_copy_elim finished after 0.013 seconds
# 2024-05-21T16:00:23Z Running mm_packing
# 2024-05-21T16:00:23Z mm_packing finished after 0.091 seconds
# 2024-05-21T16:00:23Z Running coloring_allocator_psum
# 2024-05-21T16:00:23Z coloring_allocator_psum finished after 0.066 seconds
# 2024-05-21T16:00:23Z Running dma_optimization_psum
# 2024-05-21T16:00:23Z dma_optimization_psum finished after 0.009 seconds
# 2024-05-21T16:00:23Z Running address_rotation_psum
# 2024-05-21T16:00:23Z address_rotation_psum finished after 0.041 seconds
# 2024-05-21T16:00:23Z Running coloring_allocator_sb
# 2024-05-21T16:00:23Z coloring_allocator_sb finished after 0.053 seconds
# 2024-05-21T16:00:23Z Running address_rotation_sb
# 2024-05-21T16:00:23Z address_rotation_sb finished after 0.014 seconds
# 2024-05-21T16:00:23Z Running dma_optimization_sb
# 2024-05-21T16:00:23Z dma_optimization_sb finished after 0.065 seconds
# 2024-05-21T16:00:23Z Running address_rotation_sb
# 2024-05-21T16:00:24Z address_rotation_sb finished after 0.077 seconds
# 2024-05-21T16:00:24Z Running coloring_allocator_dram
# 2024-05-21T16:00:24Z coloring_allocator_dram finished after 0.019 seconds
# 2024-05-21T16:00:24Z Running address_rotation_dram
# 2024-05-21T16:00:24Z address_rotation_dram finished after 0.008 seconds
# 2024-05-21T16:00:24Z Running tensorcopy_accel
# 2024-05-21T16:00:24Z tensorcopy_accel finished after 0.001 seconds
# 2024-05-21T16:00:24Z Running peephole_opts
# 2024-05-21T16:00:24Z peephole_opts finished after 0.008 seconds
# 2024-05-21T16:00:24Z Running lower_kernel
# 2024-05-21T16:00:24Z lower_kernel finished after 0.001 seconds
# 2024-05-21T16:00:24Z Running build_fdeps
# 2024-05-21T16:00:24Z build_fdeps finished after 0.030 seconds
# 2024-05-21T16:00:24Z Running remove_redundancies
# 2024-05-21T16:00:24Z remove_redundancies finished after 0.006 seconds
# 2024-05-21T16:00:24Z Running anti_dependency_analyzer
# 2024-05-21T16:00:24Z anti_dependency_analyzer finished after 0.145 seconds
# 2024-05-21T16:00:24Z Running tensor_copy_elim
# 2024-05-21T16:00:24Z tensor_copy_elim finished after 0.019 seconds
# 2024-05-21T16:00:24Z Running post_sched
# 2024-05-21T16:00:25Z post_sched finished after 0.690 seconds
# 2024-05-21T16:00:25Z Running address_rotation_sb
# 2024-05-21T16:00:25Z address_rotation_sb finished after 0.262 seconds
# 2024-05-21T16:00:25Z Running anti_dependency_analyzer
# 2024-05-21T16:00:25Z anti_dependency_analyzer finished after 0.123 seconds
# 2024-05-21T16:00:25Z Running dep_opt
# 2024-05-21T16:00:25Z dep_opt finished after 0.072 seconds
# 2024-05-21T16:00:25Z Running report_stats
# 2024-05-21T16:00:25Z report_stats finished after 0.002 seconds
# 2024-05-21T16:00:25Z Running assign_trigger_engine
# 2024-05-21T16:00:25Z assign_trigger_engine finished after 0.003 seconds
# 2024-05-21T16:00:25Z Running alloc_queues
# 2024-05-21T16:00:25Z alloc_queues finished after 0.002 seconds
# 2024-05-21T16:00:25Z mod_parallel_pass finished after 2.144 seconds
# 2024-05-21T16:00:25Z Running dep_reduction
# 2024-05-21T16:00:25Z dep_reduction finished after 0.186 seconds
# 2024-05-21T16:00:25Z Running bir_racecheck
# 2024-05-21T16:00:25Z bir_racecheck finished after 0.175 seconds
# 2024-05-21T16:00:25Z Running lower_dma
# 2024-05-21T16:00:25Z lower_dma finished after 0.032 seconds
# 2024-05-21T16:00:25Z Running coalesce_dma_blocks
# 2024-05-21T16:00:25Z coalesce_dma_blocks finished after 0.009 seconds
# 2024-05-21T16:00:25Z Running alloc_semaphores
# 2024-05-21T16:00:25Z alloc_semaphores finished after 0.020 seconds
# 2024-05-21T16:00:25Z Running expand_inst_late
# 2024-05-21T16:00:25Z expand_inst_late finished after 0.001 seconds
# 2024-05-21T16:00:25Z Running lower_sync
# 2024-05-21T16:00:25Z lower_sync finished after 0.006 seconds
# 2024-05-21T16:00:25Z Running lower_act
# 2024-05-21T16:00:26Z lower_act finished after 0.168 seconds
# 2024-05-21T16:00:26Z Running lower_dve
# 2024-05-21T16:00:26Z lower_dve finished after 0.047 seconds
# 2024-05-21T16:00:26Z Running lower_ap
# 2024-05-21T16:00:26Z lower_ap finished after 0.007 seconds
# 2024-05-21T16:00:26Z Running alloc_regs
# 2024-05-21T16:00:26Z alloc_regs finished after 0.000 seconds
# 2024-05-21T16:00:26Z Running birverifier
# 2024-05-21T16:00:26Z birverifier finished after 0.036 seconds
# 2024-05-21T16:00:26Z Running codegen
# 2024-05-21T16:00:26Z isa_gen finished after 0.135 seconds
# 2024-05-21T16:00:26Z dma_desc_gen finished after 0.019 seconds
# 2024-05-21T16:00:26Z debug_info_gen finished after 0.061 seconds
# 2024-05-21T16:00:26Z codegen finished after 0.226 seconds
# 2024-05-21T16:00:26Z Running neff_packager
# 2024-05-21T16:01:09Z neff_packager finished after 42.783 seconds
# 2024-05-21T16:01:14Z Compiler status PASS

# %% [markdown]
# ## Run inference and compare results
#
# In this section we load the compiled model, run inference on Neuron, and compare the CPU and Neuron outputs.

# %%
# Load the TorchScript compiled model
model_neuron = torch.jit.load(filename)

# Run inference using the Neuron model
output_neuron = model_neuron(*example)
print(f"CPU last_hidden_state:    {model_output_cpu['last_hidden_state'][0][0][:10]}")
print(f"Neuron last_hidden_state: {output_neuron['last_hidden_state'][0][0][:10]}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Load the TorchScript compiled model
# ----> 2 model_neuron = torch.jit.load(filename)
#       4 # Run inference using the Neuron model
#       5 output_neuron = model_neuron(*example)
#
# NameError: name 'torch' is not defined
